# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install sounddevice
# Out:
# Collecting numpy
#   Downloading numpy-2.4.1-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.1-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.4 MB 3.4 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/12.4 MB 2.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.8/12.4 MB 2.9 MB/s eta 0:00:04
#    -------- ------------------------------- 2.6/12.4 MB 3.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.7/12.4 MB 3.5 MB/s eta 0:00:03
#    --------------- ------------------------ 4.7/12.4 MB 3.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.5/12.4 MB 3.7 MB/s eta 0:00:02
#    -------------------- ------------------- 6.3/12.4 MB 3.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.3/12.4 MB 4.0 MB/s eta 0:00:02
#    -------------------------- ------------- 8.4/12.4 MB 4.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.4 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.4 MB 4.0 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.4 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.4 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.4 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 3.8 MB/s  0:00:03
# Installing collected packages: numpy
# Successfully installed numpy-2.4.1
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\glope\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp314-cp314-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\glope\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\glope\appdata\roaming\python\python314\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\glope\appdata\roaming\python\python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\glope\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.3 MB 6.9 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.3 MB 6.0 MB/s eta 0:00:01
#    ------------- -------------------------- 2.9/8.3 MB 5.8 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.3 MB 4.9 MB/s eta 0:00:01
#    -------------------------- ------------- 5.5/8.3 MB 5.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.3 MB 4.9 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.3 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.3 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.3 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.3 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 3.3 MB/s  0:00:02
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 3.2 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pillow-12.1.0-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.2 MB 2.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.8/7.2 MB 1.5 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/7.2 MB 1.6 MB/s eta 0:00:04
#    ------- -------------------------------- 1.3/7.2 MB 1.3 MB/s eta 0:00:05
#    ------- -------------------------------- 1.3/7.2 MB 1.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 1.8/7.2 MB 1.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 1.8/7.2 MB 1.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.1/7.2 MB 1.3 MB/s eta 0:00:05
#    -------------- ------------------------- 2.6/7.2 MB 1.3 MB/s eta 0:00:04
#    -------------- ------------------------- 2.6/7.2 MB 1.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 2.9/7.2 MB 1.2 MB/s eta 0:00:04
#    ------------------ --------------------- 3.4/7.2 MB 1.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.2/7.2 MB 1.5 MB/s eta 0:00:03
#    -------------------------- ------------- 4.7/7.2 MB 1.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.2/7.2 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 5.8/7.2 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 1.9 MB/s  0:00:04
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------- ---------------------------- 2/7 [kiwisolver]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.0 pyparsing-3.3.2
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\glope\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting sounddevice
#   Downloading sounddevice-0.5.5-py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting cffi (from sounddevice)
#   Downloading cffi-2.0.0-cp314-cp314-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi->sounddevice)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading sounddevice-0.5.5-py3-none-win_amd64.whl (365 kB)
# Downloading cffi-2.0.0-cp314-cp314-win_amd64.whl (185 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: pycparser, cffi, sounddevice
#
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ---------------------------------------- 3/3 [sounddevice]
#
# Successfully installed cffi-2.0.0 pycparser-3.0 sounddevice-0.5.5

# %%
import numpy as np
import matplotlib.pyplot as plt
import sounddevice as sd

# %%
SRATE = 41000

noise = np.random.uniform(-1,1,SRATE)

plt.plot(noise[:100])

n = noise*0.2

sd.play(n)

sd.wait()
